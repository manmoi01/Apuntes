# %%
from numpy import *
from matplotlib import pylab

# %%
a=arange(50,1050,50)
print(a)
# Out:
# [  50  100  150  200  250  300  350  400  450  500  550  600  650  700  750
#   800  850  900  950 1000]

# %%
Ai=(100+0.4)/a
print(Ai)
# Out:
# [ 2.008       1.004       0.66933333  0.502       0.4016      0.33466667
#   0.28685714  0.251       0.22311111  0.2008      0.18254545  0.16733333
#   0.15446154  0.14342857  0.13386667  0.1255      0.11811765  0.11155556
#   0.10568421  0.1004    ]

# %%
pylab.plot(a,Ai)

# %%
Rc=1333.0
Rl=1000.0
Re=336.33
hie=1000.0
beta=100.0
Rth=176000.0

# %%
Rp=(Rth*(hie+((beta+1)*Re)))/(Rth+(hie+((beta+1)*Re)))
print(Rp)
# Out:
# 29172.97068725582

# %%
Ri=arange(0,100000,50)

# %%
Av=beta*((Rc*Rl)/(Rc+Rl))*(((Rp)/(Rp+Ri))/((hie+((beta+1)*Re))))

# %%
plot(a,Av)

# %%
Rc=1333.0
Rl=1000.0
Re=336.33
hie=250.0
beta=100.0
Rth=176000.0
Rp=(Rth*(hie+((beta+1)*Re)))/(Rth+(hie+((beta+1)*Re)))
print(Rp)
Ri=arange(0,100000,50)
Av=beta*((Rc*Rl)/(Rc+Rl))*(((Rp)/(Rp+Ri))/((hie+((beta+1)*Re))))
plot(Ri,Av)
# Out:
# 28649.13554809636
